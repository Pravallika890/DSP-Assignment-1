# %%
coords=[[15.922126611273297, 80.0692514667603],[16.007114734450337, 80.11085027629855],
        [16.042099346323678, 80.13164968021844],[16.072081269044702, 80.14204938217839],
        [16.082074239335327, 80.15244908413833],[16.266853269325253, 80.35524327235728],
        [16.436497095271466, 80.56843716253616],[16.461432262333926, 80.599636268416],
        [16.514300801775875, 80.65208762992584],[16.561694063927387, 80.6740602847404],
        [16.59591528415698, 80.70152610325862],[16.61170763994698, 80.7125124306659],
        [16.65907691197555, 80.73997824918409],[16.67223296513543, 80.78117697696142],
        [16.703803800587956, 80.79765646807233],[16.74062984453576, 80.81962912288691],
        [16.782708035073053, 80.84709494140512]]
coords_1=[[15.922126611273297,80.0692514667603],[15.99221415342011,80.10002467770985],
        [16.00013485718639, 80.15220973289445],[15.969770840036976, 80.25379900155896],
        [16.033134792745628, 80.31697038415085],[16.114950093393958, 80.3252101297063],
        [16.26793314640274, 80.42683365822367],[16.304842283465806, 80.52845718674105],
        [16.294297524668217, 80.63832046081389],[16.40235435021942, 80.62458755155478],
        [16.418162523687226, 80.58338882377747],[16.470847148003532, 80.62184096970294],
        [16.494550559725635, 80.6273341334066],[16.568275923574735, 80.67127944303574],
        [16.618287788185818, 80.71522475266487],[16.589335136159026, 80.69874526155394],
        [16.72879406039015, 80.81684828118223],[16.78665277086874, 80.85255384525591]]
coords_2=[[15.922126611273297,80.0692514667603],[15.989845247065572, 80.102829083375],
          [16.03307309166259, 79.91450681684576],[16.048972638215396, 79.73744161341665],
          [16.122865915017474, 79.92420917934047],[16.236291219357156, 80.0478053626724],
          [16.397084673681935, 80.13294940007886],[16.54194866942812, 80.13020281822703],
          [16.589335136159026, 80.32246354785448],[16.63407830408684, 80.4295802400755],
          [16.59723174658351, 80.51472427748195],[16.718272405983228, 80.61634780599933],
          [16.768245089874252, 80.67402602488757],[16.776134314333614, 80.73994398933125],
          [16.770874867737103, 80.7207179163685],[16.847122582315787, 80.76191664414581],
          [16.81031716789304, 80.80860853562677],[16.78665277086874, 80.85255384525591]]

# %%
import folium
from branca.element import Figure
f1=folium.FeatureGroup("Root 1")
f2=folium.FeatureGroup("Root 2")
f3=folium.FeatureGroup("Root 3")
fig5=Figure(height=550,width=750)
map5=folium.Map(location=[15.922126611273297, 80.0692514667603],tiles='cartodbpositron',zoom_start=14)
folium.Marker(location=[15.922126611273297, 80.0692514667603],popup='Default popup Marker1',tooltip='Click here to see more details',icon=folium.Icon(color='red',icon='none')).add_to(map5)
folium.Marker(location=[16.782708035073053, 80.84709494140512],popup='<strong>Marker2</strong>',tooltip='Click here to see more details',icon=folium.Icon(color='orange',prefix='glyphicon',icon='off')).add_to(map5)
folium.Marker(location=[15.922126611273297, 80.0692514667603],popup='<strong>Marker1</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='off')).add_to(map5)
folium.Marker(location=[16.61170763994698, 80.7125124306659],popup='hospital',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='green',prefix='fa',icon='ambulance')).add_to(map5)
folium.Marker(location=[16.782708035073053, 80.84709494140512],popup='iiit nuzvid',tooltip='<strong>iiit nuz</strong>',icon=folium.Icon(color='green',prefix='fa',icon='university')).add_to(map5)
folium.Marker(location=[16.236291219357156, 80.0478053626724],popup='temple',tooltip='<strong>ramalayam</strong>',icon=folium.Icon(color='red',prefix='fa',icon='bell')).add_to(map5)



line_1=folium.vector_layers.PolyLine(coords,tooltip='Root_1',color='blue',weight=5).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords_1,popup='<b>Path of Root_2</b>',tooltip='Root_2',color='red',weight=10).add_to(f2)
line_3=folium.vector_layers.PolyLine(coords_2,popup='<b>Path of Root_3</b>',tooltip='Root_3',color='pink',weight=15).add_to(f3)
f1.add_to(map5)
f2.add_to(map5)
f3.add_to(map5)
folium.LayerControl().add_to(map5)
fig5.add_child(map5)
map5
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
